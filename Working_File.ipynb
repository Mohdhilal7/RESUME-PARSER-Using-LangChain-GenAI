# %% [markdown]
# # 1 Google API

# %%
from langchain_google_genai.chat_models import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os

# Load .env
load_dotenv()

# Fetch API key
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# Initialize the model
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",
    google_api_key=GOOGLE_API_KEY
)

# Test query
user_query = "What is AI"
response = model.invoke(user_query).content

print(response)
# Out:
# AI stands for **Artificial Intelligence**.
#
# In simple terms, AI refers to the development of computer systems that can perform tasks that typically require human intelligence. These tasks include things like:
#
# *   **Learning:** Acquiring knowledge and skills from data.
# *   **Problem-solving:** Finding solutions to challenges.
# *   **Decision-making:** Choosing the best course of action.
# *   **Perception:** Understanding sensory input like images, sounds, and text.
# *   **Natural Language Understanding (NLU):** Comprehending and processing human language.
# *   **Reasoning:** Drawing logical conclusions.
#
# **Think of it this way:** Instead of explicitly programming a computer for every single scenario, AI aims to create systems that can learn and adapt, much like humans do.
#
# **Key Concepts and Goals of AI:**
#
# *   **Mimicking Human Intelligence:** The ultimate goal is to create machines that can think, reason, and act in ways comparable to humans.
# *   **Automation:** AI can automate complex tasks, leading to increased efficiency and productivity in various industries.
# *   **Pattern Recognition:** AI excels at identifying patterns in vast amounts of data, which is crucial for tasks like image recognition, fraud detection, and medical diagnosis.
# *   **Adaptability:** AI systems can learn from new data and experiences, allowing them to improve their performance over time without constant human intervention.
#
# **Types of AI:**
#
# While the ultimate goal is "strong AI" (machines with human-level general intelligence), most of what we see today is **Narrow AI** or **Weak AI**.
#
# *   **Narrow AI (Weak AI):** This type of AI is designed and trained for a specific task. Examples include:
#     *   Virtual assistants like Siri and Alexa.
#     *   Recommendation engines on Netflix or Amazon.
#     *   Image recognition software.
#     *   Spam filters.
#     *   Self-driving cars (though these are becoming increasingly sophisticated).
# *   **General AI (Strong AI):** This is theoretical AI that would possess the ability to understand, learn, and apply intelligence to any intellectual task that a human being can. It's still a long way off.
# *   **Superintelligence:** This is a hypothetical AI that would surpass human intelligence in all aspects, including creativity, general wisdom, and problem-solving. This is even further into the realm of speculation.
#
# **How AI Works (Broadly):**
#
# AI systems often rely on:
#
# *   **Machine Learning (ML):** A subset of AI where systems learn from data without being explicitly programmed. Algorithms identify patterns and make predictions or decisions.
# *   **Deep Learning (DL):** A subset of ML that uses artificial neural networks with multiple layers (hence "deep") to process complex data like images and speech.
# *   **Algorithms:** Sets of rules or instructions that a computer follows to perform a task.
#
# **Applications of AI:**
#
# AI is rapidly transforming many aspects of our lives and industries, including:
#
# *   **Healthcare:** Drug discovery, diagnosis, personalized medicine.
# *   **Finance:** Fraud detection, algorithmic trading, risk assessment.
# *   **Transportation:** Self-driving vehicles, traffic management.
# *   **Customer Service:** Chatbots, personalized recommendations.
# *   **Entertainment:** Game AI, content creation.
# *   **Education:** Personalized learning platforms, automated grading.
# *   **Manufacturing:** Robotics, quality control.
#
# **In summary, AI is the science and engineering of creating intelligent machines, with the aim of enabling computers to perform tasks that would normally require human cognitive abilities.** It's a rapidly evolving field with the potential to revolutionize many areas of our world.

# %%
user_query = "What is AI"
response = model.invoke(user_query).content

print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 user_query = "What is AI"
# ----> 2 response = model.invoke(user_query).content
#       4 print(response)
#
# NameError: name 'model' is not defined

# %% [markdown]
# # 2 Openai API

# %% [markdown]
# # 3 Anthropic API
